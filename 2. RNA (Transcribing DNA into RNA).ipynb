# %%
def transcribe(t):
    u = t.replace('T', 'U')
    return u

# %%
#string = "GATGGAACTTGACTACGTAAATT"
lines = []
with open("./rosalind_rna.txt", "r") as file:
    for line in file:
        lines.append(line.strip())
string = lines[0]

string
# Out:
# '...'

# %%
transcribe(string)
# Out:
# '...'
